# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !pip install -qU langchain-google-vertexai

# %%
# !pip install langchain
# !pip install -qU langchain-google-vertexai
from langchain_google_vertexai import ChatVertexAI
import vertexai

# Replace 'YOUR_PROJECT_ID' with your actual Google Cloud Project ID
vertexai.init(project="simple-llm-using-langchain")  # Authenticate and set the project

model = ChatVertexAI(model="gemini-pro")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7ac064a77dc0>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# ...

# %%
# !pip install langchain
# !pip install -qU langchain-google-vertexai
# !pip install langchain_community
from langchain_google_vertexai import ChatVertexAI
import vertexai
from langchain.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# Authenticate using your preferred method. Here's an example using Application Default Credentials:
import google.auth
credentials, project_id = google.auth.default()

# If you have a specific project, set it here:
# project_id = 'YOUR_PROJECT_ID'

vertexai.init(project=project_id, credentials=credentials)

# If you want to use a Vertex AI model, uncomment the line below:
# model = ChatVertexAI(model="gemini-pro")

# Alternatively, for testing, you can use OpenAI model (make sure you have the OPENAI_API_KEY environment variable set):
model = ChatOpenAI(temperature=0)

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.9 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-11-05d8c15ba135> in <cell line: 22>()
#      20
#      21 # Alternatively, for testing, you can use OpenAI model (make sure you have the OPENAI_API_KEY environment variable set):
# ---> 22 model = ChatOpenAI(temperature=0)
#      23
# ...
